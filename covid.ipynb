# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
global_data = pd.read_csv("HIST_PAINEL_COVIDBR_19mai2020.csv")

# %%
global_data.head()
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  obitosAcumulado  \
# 0  2020-02-26          9       210147125.0               1                0
# 1  2020-02-27          9       210147125.0               1                0
# 2  2020-02-28          9       210147125.0               1                0
# 3  2020-02-29          9       210147125.0               2                0
# 4  2020-03-01         10       210147125.0               2                0
#
#    Recuperadosnovos  emAcompanhamentoNovos
# ...

# %%
global_data.tail()
# Out:
#              regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 92382  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 92383  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 92384  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 92385  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 92386  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#       nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 92382        Brasília  2020-05-15         20         3015268.0
# 92383        Brasília  2020-05-16         20         3015268.0
# 92384        Brasília  2020-05-17         21         3015268.0
# 92385        Brasília  2020-05-18         21         3015268.0
# 92386        Brasília  2020-05-19         21         3015268.0
#
#        casosAcumulado  obitosAcumulado  Recuperadosnovos  \
# 92382            3787               55               NaN
# ...

# %%
global_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92387 entries, 0 to 92386
# Data columns (total 14 columns):
# regiao                   92387 non-null object
# estado                   92303 non-null object
# municipio                89963 non-null object
# coduf                    92387 non-null int64
# codmun                   90488 non-null float64
# codRegiaoSaude           89963 non-null float64
# nomeRegiaoSaude          89963 non-null object
# data                     92387 non-null object
# semanaEpi                92387 non-null int64
# populacaoTCU2019         91862 non-null float64
# casosAcumulado           92387 non-null int64
# obitosAcumulado          92387 non-null int64
# Recuperadosnovos         31 non-null float64
# emAcompanhamentoNovos    31 non-null float64
# dtypes: float64(5), int64(4), object(5)
# memory usage: 9.9+ MB

# %%
global_data.describe()
# Out:
#               coduf         codmun  codRegiaoSaude     semanaEpi  \
# count  92387.000000   90488.000000    89963.000000  92387.000000
# mean      31.373786  315068.657811    31390.177551     18.314341
# std        9.784864   96551.074250     9634.210352      1.964375
# min       11.000000  110000.000000    11001.000000      9.000000
# 25%       24.000000  241105.000000    24006.000000     17.000000
# 50%       31.000000  314700.000000    31052.000000     19.000000
# 75%       41.000000  410190.000000    41002.000000     20.000000
# max       76.000000  530010.000000    53001.000000     21.000000
#
#        populacaoTCU2019  casosAcumulado  obitosAcumulado  Recuperadosnovos  \
# count      9.186200e+04    92387.000000     92387.000000         31.000000
# mean       4.481149e+05      138.384015         9.222661      52386.806452
# std        6.605114e+06     2844.351946       197.967164      25408.108023
# min        1.112000e+03        1.000000         0.000000      22130.000000
# ...

# %%
brasil = global_data[global_data['regiao'] == "Brasil"]
brasil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84 entries, 0 to 83
# Data columns (total 14 columns):
# regiao                   84 non-null object
# estado                   0 non-null object
# municipio                0 non-null object
# coduf                    84 non-null int64
# codmun                   0 non-null float64
# codRegiaoSaude           0 non-null float64
# nomeRegiaoSaude          0 non-null object
# data                     84 non-null object
# semanaEpi                84 non-null int64
# populacaoTCU2019         84 non-null float64
# casosAcumulado           84 non-null int64
# obitosAcumulado          84 non-null int64
# Recuperadosnovos         31 non-null float64
# emAcompanhamentoNovos    31 non-null float64
# dtypes: float64(5), int64(4), object(5)
# memory usage: 9.8+ KB

# %%
brasil = brasil.drop(['municipio', 'estado', 'codmun', 'codRegiaoSaude', 'nomeRegiaoSaude'], axis = 1)

# %%
brasil = brasil.fillna(0)

# %%
val_datas = range(84)
brasil['data'] = val_datas

# %%
brasil.plot.scatter(x='data', y='casosAcumulado')

# %%
regioes = global_data['regiao']
values = regioes.value_counts() #value_coounts mostra o que há na coluna
print(values)
# Out:
# Nordeste        31555
# Sudeste         27993
# Sul             18002
# Norte            9295
# Centro-Oeste     5458
# Brasil             84
# Name: regiao, dtype: int64

# %%
global_data.data.tail()


#print("mun")
#ultima data observada 2020-05-19
# Out:
# 92382    2020-05-15
# 92383    2020-05-16
# 92384    2020-05-17
# 92385    2020-05-18
# 92386    2020-05-19
# Name: data, dtype: object

# %%
regiao_work_data = global_data.fillna('Vazio')
regiao_work_data.head()
# Out:
#    regiao estado municipio  coduf codmun codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil  Vazio     Vazio     76  Vazio          Vazio           Vazio
# 1  Brasil  Vazio     Vazio     76  Vazio          Vazio           Vazio
# 2  Brasil  Vazio     Vazio     76  Vazio          Vazio           Vazio
# 3  Brasil  Vazio     Vazio     76  Vazio          Vazio           Vazio
# 4  Brasil  Vazio     Vazio     76  Vazio          Vazio           Vazio
#
#          data  semanaEpi populacaoTCU2019  casosAcumulado  obitosAcumulado  \
# 0  2020-02-26          9      2.10147e+08               1                0
# 1  2020-02-27          9      2.10147e+08               1                0
# 2  2020-02-28          9      2.10147e+08               1                0
# 3  2020-02-29          9      2.10147e+08               2                0
# 4  2020-03-01         10      2.10147e+08               2                0
#
#   Recuperadosnovos emAcompanhamentoNovos
# ...

# %%
casos_por_regiao = pd.DataFrame({"Regiao":['Nordeste', 'Sudeste', 'Sul', 'Norte','Centro-Oeste'], "Num_Casos":[0, 0, 0, 0, 0]}) 
print(casos_por_regiao)
acumulado = [0, 0, 0, 0, 0]

for index, row in regiao_work_data.iterrows():
    if row['regiao'] != 'Brasil' and row['data'] == "2020-05-19" and row['municipio'] == 'Vazio':
        if row['regiao'] == 'Nordeste': 
            acumulado[0] += row['casosAcumulado']   
            casos_por_regiao.loc[0, 'Num_Casos'] = acumulado[0]   
            
        if row['regiao'] == 'Sudeste':  
           # print(row['estado'], row['casosAcumulado'])
            acumulado[1] += row['casosAcumulado']
            casos_por_regiao.loc[1, 'Num_Casos'] = acumulado[1]
                     
        if row['regiao'] == 'Sul': 
            acumulado[2] += row['casosAcumulado']
            casos_por_regiao.loc[2, 'Num_Casos'] = acumulado[2]
                     
        if row['regiao'] == 'Norte':
            acumulado[3] += row['casosAcumulado']
            casos_por_regiao.loc[3, 'Num_Casos'] = acumulado[3]
                    
        if row['regiao'] == 'Centro-Oeste':
            acumulado[4] += row['casosAcumulado']
            casos_por_regiao.loc[4, 'Num_Casos'] = acumulado[4]
print(acumulado)
# Out:
#          Regiao  Num_Casos
# 0      Nordeste          0
# 1       Sudeste          0
# 2           Sul          0
# 3         Norte          0
# 4  Centro-Oeste          0
# [95142, 106854, 11682, 51129, 8361]

# %%
casos_por_regiao.head()
# Out:
#          Regiao  Num_Casos
# 0      Nordeste      95142
# 1       Sudeste     106854
# 2           Sul      11682
# 3         Norte      51129
# 4  Centro-Oeste       8361

# %%
ax = casos_por_regiao.plot.bar(x='Regiao', y='Num_Casos', rot=0)
